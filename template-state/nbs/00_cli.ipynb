# %%
#| echo: false
# %load_ext watermark
# %watermark -a 'cs224' -u -d -v -p numpy,pandas,scipy,nbdev,matplotlib

# %%
#| hide
# %matplotlib inline
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %%
#| hide
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
np.set_printoptions(edgeitems=10, linewidth=1000, suppress=True)
np._core.arrayprint._line_width = 180
sns.set()

# %%
#| hide
from IPython.display import display, HTML

# %%
#| hide
for css in ["<style>.container { width:70% !important; }</style>", "<style>:root { --jp-notebook-max-width: 70% !important; }</style>"]:
    display(HTML(css))

# %%
#| hide
from pytest import approx

# %%
#| hide
APPROX = {"rel": 1e-9, "abs": 1e-12}

# %%
#| hide
assert approx(0.1, **APPROX) == 0.1
assert 0.1 == approx(0.1, **APPROX)

# %% [markdown]
# # CLI
#
# A tiny Hello World CLI implemented with `argparse`.

# %%
#| default_exp cli

# %%
#| export
from __future__ import annotations

import argparse


def build_parser() -> argparse.ArgumentParser:
    parser = argparse.ArgumentParser(description="{{ description }}")
    parser.add_argument("--name", help="Optional name to greet.")
    return parser


def main(argv: list[str] | None = None) -> int:
    args = build_parser().parse_args(argv)
    name = args.name or "World"
    print(f"Hello {name}!")
    return 0
