# %% [markdown]
# # Notebook tests
#
# These tests run under `nbdev_test`.

# %%
#| hide
from {{ package_name }}.cli import main

# %%
# Default output
_ = main([])

# %%
# Named output
_ = main(["--name", "Alice"])
